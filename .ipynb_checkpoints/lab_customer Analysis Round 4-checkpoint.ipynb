# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading csv as a dataframe
data = pd.read_csv('marketing_customer_analysis.csv')
data
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  Income  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
data = data.drop(['Unnamed: 0'], axis=1)

# %%
data
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  \
# ...

# %%
# shape of the dataframe
data.shape
# Out:
# (10910, 25)

# %%
# Standardization of header names
def standardization(df):
    df.columns = df.columns.str.lower()
    df.columns = df.columns.str.replace(' ','_')

# %%
standardization(data)
data
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  \
# ...

# %%
#Which columns are numerical or categorical?
def num_or_cat(df):
    categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
    numerical_columns = df.select_dtypes(exclude=['object']).columns.tolist()
    return numerical_columns, categorical_columns

# %%
num_or_cat(data)
# Out:
# (['customer_lifetime_value',
#   'income',
#   'monthly_premium_auto',
#   'months_since_policy_inception',
#   'number_of_policies',
#   'total_claim_amount',
#   'month'],
#  ['customer',
#   'state',
#   'response',
#   'coverage',
#   'education',
#   'effective_to_date',
#   'employmentstatus',
#   'gender',
#   'location_code',
#   'marital_status',
#   'policy_type',
#   'policy',
#   'renew_offer_type',
#   'sales_channel',
#   'vehicle_class',
#   'vehicle_size'])

# %%
#Check and deal with NaN values.
def nulls_data(df):
    nulls_df = pd.DataFrame(round(df.isna().sum()/len(df)*100,2))
    nulls_df = nulls_df.reset_index()
    nulls_df.columns = ['header_name', '%_null_values'] 
    return nulls_df

# %%
res_null=nulls_data(data)
res_null
# Out:
#                       header_name  %_null_values
# 0                        customer           0.00
# 1                           state           5.78
# 2         customer_lifetime_value           0.00
# 3                        response           5.78
# 4                        coverage           0.00
# 5                       education           0.00
# 6               effective_to_date           0.00
# 7                employmentstatus           0.00
# 8                          gender           0.00
# 9                          income           0.00
# 10                  location_code           0.00
# 11                 marital_status           0.00
# 12           monthly_premium_auto           0.00
# 13        months_since_last_claim           5.80
# 14  months_since_policy_inception           0.00
# 15      number_of_open_complaints           5.80
# 16             number_of_policies           0.00
# 17                    policy_type           0.00
# ...

# %%
columns_drop = res_null[res_null['%_null_values']>5]['header_name']
columns_drop
# Out:
# 1                         state
# 3                      response
# 13      months_since_last_claim
# 15    number_of_open_complaints
# 22                vehicle_class
# 23                 vehicle_size
# 24                 vehicle_type
# Name: header_name, dtype: object

# %%
# The column 'vehicle_type' is dropped because of the high percentage of missing data
data = data.drop(['vehicle_type'],axis=1)
# The numerical columns with the percentage of missing data higher than 5 are dropped
data = data.drop(['months_since_last_claim', 'number_of_open_complaints'],axis=1)

# %%
data
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  \
# ...

# %%
# Fixing NAN values which are categorical and replacing them with 'None'
def null_cat_fix(df):
    cat_cols= df.select_dtypes(include=['object']).columns.tolist()
    for col in cat_cols:
        df[col] = df[col].fillna('None')
    return df

# %%
null_cat_fix(data)
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877        None              6857.519928     None     Basic
#
#       education effective_to_date employmentstatus gender  income  \
# ...

# %%
nulls_data(data)
# Out:
#                       header_name  %_null_values
# 0                        customer            0.0
# 1                           state            0.0
# 2         customer_lifetime_value            0.0
# 3                        response            0.0
# 4                        coverage            0.0
# 5                       education            0.0
# 6               effective_to_date            0.0
# 7                employmentstatus            0.0
# 8                          gender            0.0
# 9                          income            0.0
# 10                  location_code            0.0
# 11                 marital_status            0.0
# 12           monthly_premium_auto            0.0
# 13  months_since_policy_inception            0.0
# 14             number_of_policies            0.0
# 15                    policy_type            0.0
# 16                         policy            0.0
# 17               renew_offer_type            0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10910 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10910 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective_to_date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
# ...

# %%
data['effective_to_date']
# Out:
# 0        2/18/11
# 1        1/18/11
# 2        2/10/11
# 3        1/11/11
# 4        1/17/11
#           ...
# 10905    1/19/11
# 10906     1/6/11
# 10907     2/6/11
# 10908    2/13/11
# 10909     1/8/11
# Name: effective_to_date, Length: 10910, dtype: object

# %%
# Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.
def month_extract(df,col_date):
    df['month'] = pd.DatetimeIndex(df[col_date]).month
    return df

# %%
data=month_extract(data,'effective_to_date')
data
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877        None              6857.519928     None     Basic
#
#       education effective_to_date employmentstatus gender  income  \
# ...

# %%
data['month']
# Out:
# 0        2
# 1        1
# 2        2
# 3        1
# 4        1
#         ..
# 10905    1
# 10906    1
# 10907    2
# 10908    2
# 10909    1
# Name: month, Length: 10910, dtype: int64

# %%
#Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.
data_filter=data[data['month']<=3]
data_filter
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877        None              6857.519928     None     Basic
#
#       education effective_to_date employmentstatus gender  income  \
# ...

# %%
# the month of the all data in the dataframe is within the first quarter

# %%
#Show DataFrame info.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10910 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10910 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective_to_date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
# ...

# %%
#Describe DataFrame.
summary = data.describe().T
summary
# Out:
#                                  count          mean           std  \
# customer_lifetime_value        10910.0   8018.241094   6885.081434
# income                         10910.0  37536.284785  30359.195670
# monthly_premium_auto           10910.0     93.196059     34.442532
# months_since_policy_inception  10910.0     48.091934     27.940675
# number_of_policies             10910.0      2.979193      2.399359
# total_claim_amount             10910.0    434.888330    292.180556
# month                          10910.0      1.466728      0.498915
#
#                                        min          25%           50%  \
# customer_lifetime_value        1898.007675  4014.453113   5771.147235
# income                            0.000000     0.000000  33813.500000
# monthly_premium_auto             61.000000    68.000000     83.000000
# months_since_policy_inception     0.000000    24.000000     48.000000
# number_of_policies                1.000000     1.000000      2.000000
# ...

# %%
#Show a plot of the total number of responses.NA was filled by 'None' above.
data['response'].hist(bins=10,figsize=(5,3))
plt.title('total number of responses', fontsize = 13)
plt.show()

# %%
#Show a plot of the total number of responses.--> another way
resp = list(data.response.value_counts().index)
c = list(data.response.value_counts())
plt.bar(resp,c)
plt.show()

# %%
# Show a plot of the response rate by the sales channel
response_sales = data.groupby(['response','sales_channel']).size().reset_index(name = 'counts')

# %%
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.barplot(x=response_sales["sales_channel"], y = response_sales["counts"], hue=response_sales['response'], alpha=0.7)
ax.set_title('The response rate by the sales channel')
# Out:
# Text(0.5, 1.0, 'The response rate by the sales channel')

# %%
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=response_sales["sales_channel"], y = response_sales["counts"])
ax.set_title('The response rate by the sales channel')
# Out:
# Text(0.5, 1.0, 'The response rate by the sales channel')

# %%
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=response_sales["sales_channel"], y = response_sales["counts"],hue=response_sales['response'])
ax.set_title('The response rate by the sales channel')
# Out:
# Text(0.5, 1.0, 'The response rate by the sales channel')

# %%
#Show a plot of the response rate by the total claim amount.
response_claim = data.groupby(['response','total_claim_amount']).size().reset_index(name = 'counts')

# %%
f1, ax1 = plt.subplots(figsize=(8, 6))
fig1 = sns.barplot(x=response_claim["total_claim_amount"], y = response_claim["counts"],hue=response_claim['response'])
ax1.set(ylim=(0,50),xticks=[10000])

ax1.set_title('The response rate by the total claim amount')
# Out:
# Text(0.5, 1.0, 'The response rate by the total claim amount')

# %%
f1, ax1 = plt.subplots(figsize=(8, 6))
fig1 = sns.scatterplot(x=response_claim["total_claim_amount"], y = response_claim["counts"])
ax1.set(ylim=(0,150),xticks=[100000])

ax1.set_title('The response rate by the total claim amount')
# Out:
# Text(0.5, 1.0, 'The response rate by the total claim amount')

# %%
len(data.total_claim_amount.unique())
# Out:
# 5106

# %%
data['total_claim_amount']
# Out:
# 0         292.800000
# 1         744.924331
# 2         480.000000
# 3         484.013411
# 4         707.925645
#             ...
# 10905    1214.400000
# 10906     273.018929
# 10907     381.306996
# 10908     618.288849
# 10909    1021.719397
# Name: total_claim_amount, Length: 10910, dtype: float64

# %%
#Show a plot of the response rate by income.
response_income = data.groupby(['response','income']).size().reset_index(name = 'counts')

# %%
f2, ax2 = plt.subplots(figsize=(8, 6))
fig2 = sns.barplot(x=response_income["income"], y = response_income["counts"],hue=response_income['response'])
ax2.set_title('The response rate by income')
ax2.set(ylim=(0,10),xticks=[10000])
# Out:
# [(0.0, 10.0), [<matplotlib.axis.XTick at 0x1752827e670>]]

# %%
f2, ax2 = plt.subplots(figsize=(8, 6))
fig2 = sns.scatterplot(x=response_income["income"], y = response_income["counts"])
ax2.set_title('The response rate by income')
ax2.set(ylim=(0,10),xticks=[10000])
# Out:
# [(0.0, 10.0), [<matplotlib.axis.XTick at 0x17549ced190>]]

# %% [markdown]
# Check the data types of the columns. Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. (You can use np.number and np.object to select the numerical data types and categorical data types respectively).

# %%
categorical_columns = data.select_dtypes(include=['object']).columns.tolist()
numerical_columns = data.select_dtypes(exclude=['object']).columns.tolist()
numerical = data.drop(categorical_columns, axis=1)
categorical = data.drop(numerical_columns, axis=1)
numerical
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months_since_policy_inception  number_of_policies  total_claim_amount  \
# 0                                 52                   9          292.800000
# ...

# %%
categorical
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877        None     None     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location_code marital_status     policy_type  \
# ...

# %%
numerical = numerical.drop(['month'], axis=1)
numerical
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months_since_policy_inception  number_of_policies  total_claim_amount
# 0                                 52                   9          292.800000
# 1                                 26                   1          744.924331
# ...

# %%
numerical_columns.pop()
# Out:
# 'month'

# %%
numerical_columns
# Out:
# ['customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'months_since_policy_inception',
#  'number_of_policies',
#  'total_claim_amount']

# %%
#Now we will try to check the normality of the numerical variables visually
#Use seaborn library to construct distribution plots for the numerical variables
for col in numerical_columns:
    sns.distplot(numerical[col],bins= 100, 
                   color = 'blue')
    plt.title('Distribution')
    plt.show()

# %%
#Use Matplotlib to construct histograms
numerical.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017557ADED00>,
# ...
#       dtype=object)

# %%
# Do the distributions for different numerical variables look like a normal distribution
#Answer: no, it does not, and they are skewed.

# %%
#For the numerical variables, check the multicollinearity between the features. Please note that we will use the column total_claim_amount later as the target variable.
# correlation between different variables
f, ax = plt.subplots(figsize=(20, 15))
mat = numerical.corr('pearson')
mask = np.triu(np.ones_like(mat, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(mat, mask=mask, cmap=cmap, vmax=1, center=0, annot = True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
# Another way to check -VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_variables = numerical.drop(['total_claim_amount'],axis=1)

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = X_variables.columns
vif_data["VIF"] = [variance_inflation_factor(X_variables.values, i) for i in range(len(X_variables.columns))]
vif_data
# Out:
#                          feature       VIF
# 0        customer_lifetime_value  2.819270
# 1                         income  2.243612
# 2           monthly_premium_auto  5.698837
# 3  months_since_policy_inception  3.184200
# 4             number_of_policies  2.236750

# %%
# These VIF values should be checked to be less than max of 10 and 1/1-R²model

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
target = numerical['total_claim_amount']
x = X_variables

# %%
lm = linear_model.LinearRegression()
lm.fit(x,target)
# Out:
# LinearRegression()

# %%
import statsmodels.api as sm 
from statsmodels.formula.api import ols
X = sm.add_constant(x)
model = sm.OLS(target,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     total_claim_amount   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.520
# Method:                 Least Squares   F-statistic:                     2367.
# Date:                Fri, 03 Dec 2021   Prob (F-statistic):               0.00
# Time:                        14:47:35   Log-Likelihood:                -73411.
# No. Observations:               10910   AIC:                         1.468e+05
# Df Residuals:                   10904   BIC:                         1.469e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                            68.9127      7.375      9.345      0.000      54.457      83.368
# ...

# %%
max(10,1.37)
# Out:
# 10

# %%
# so, all the numerical features have VIF less than max of 10 and 1/1-R²model

# %% [markdown]
# Drop one of the two features that show a high correlation between them (greater than 0.9). Write code for both the correlation matrix and for seaborn heatmap. If there is no pair of features that have a high correlation, then do not drop any features

# %%
#No high correlation was observed between pair of features, so none of them was dropped. monthly_premium_auto has the highest correlation with the target.
